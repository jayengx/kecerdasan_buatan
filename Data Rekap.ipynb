# %% [markdown]
# ## Plotting data

# %%
# create simple plot

import matplotlib.pyplot as plt

x = [10, 11, 12, 20]
y = [20, 22, 21, 21]

plt.plot(x, y)
plt.show()

# %%
data_rekap = [
    {
        "tahun": 1995,
        "penjualan": 300,
        "operasional": 150,
        "pajak": 50,
        "pendapatan_lain": 135
    },
    {
        "tahun": 1997,
        "penjualan": 320,
        "operasional": 120,
        "pajak": 65,
        "pendapatan_lain": 105
    },
    {
        "tahun": 1991,
        "penjualan": 200,
        "operasional": 75,
        "pajak": 35,
        "pendapatan_lain": 85
    },
    {
        "tahun": 1992,
        "penjualan": 320,
        "operasional": 170,
        "pajak": 80,
        "pendapatan_lain": 235
    },
    {
        "tahun": 2001,
        "penjualan": 300,
        "operasional": 150,
        "pajak": 52,
        "pendapatan_lain": 135
    },
    {
        "tahun": 2003,
        "penjualan": 500,
        "operasional": 350,
        "pajak": 110,
        "pendapatan_lain": 55
    },
    {
        "tahun": 2005,
        "penjualan": 750,
        "operasional": 450,
        "pajak": 181,
        "pendapatan_lain": 155
    }
]

# %%
# data_graph = {
#     "years": [],
#     "sales": []
# }

# %%
# mapping data {tahun: penjualan}
data_map = {data["tahun"]: data["penjualan"] for data in data_rekap}
data_map
# Out:
# {1995: 300, 1997: 320, 1991: 200, 1992: 320, 2001: 300, 2003: 500, 2005: 750}

# %%
# sorting years
years = list(data_map.keys())
years.sort()
years
# Out:
# [1991, 1992, 1995, 1997, 2001, 2003, 2005]

# %%
data_graph = {}
for year in years:
    sales_list = data_graph.get("sales",[])
    years_list = data_graph.get("years", [])
    years_list.append(year)
    sales_list.append(data_map[year])
    data_graph["sales"] = sales_list
    data_graph["years"] = years_list

data_graph
# Out:
# {'sales': [200, 320, 300, 320, 300, 500, 750],
#  'years': [1991, 1992, 1995, 1997, 2001, 2003, 2005]}

# %%
plt.plot(data_graph["years"], data_graph["sales"], label="penjualan")
plt.plot(data_graph["years"], [i * 100 for i in range(len(years))], label="dummy")

plt.xlabel("Tahun")
plt.ylabel("Dalam nominal jutaan rupiah")
plt.title("Data Rekapitulasi")
plt.legend()
plt.show()

# %%
# data_graph = {
#     "years": [],
#     "sales": [],
#     "income": [],
#     "profit": []
# }

# income = penjualan + pendapatan_lain
# profit = income - pajak - operasional
