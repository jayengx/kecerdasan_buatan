# %% [markdown]
# ## Data Siswa
# ### Link
# ### https://github.com/agungperdananto/Kecerdasan-Buatan/

# %%
students = [
    {
        "nim": 2046363636,
        "nama": "Iwan",
        "semester": 6,
        "hasil": [
            {
                "mata_kuliah": "kecerdasan buatan",
                "hadir": 18,
                "sks": 3,
                "nilai":{
                    "tugas": 75,
                    "uts": 80,
                    "uas": 77
                }
            },
            {
                "mata_kuliah": "basis data 1",
                "hadir": 20,
                "sks": 3,
                "nilai":{
                    "tugas": 80,
                    "uts": 82,
                    "uas": 67
                }
            },
            {
                "mata_kuliah": "digital enterpreneur",
                "hadir": 14,
                "sks": 2,
                "nilai":{
                    "tugas": 90,
                    "uts": 82,
                    "uas": 80
                }
            }
            ]
            },
        {
        "nim": 2046363777,
        "nama": "Saepulloh",
        "semester": 2,
        "hasil": [
            {
                "mata_kuliah": "algoritma & pemrogaman 1",
                "hadir": 20,
                "sks": 3,
                "nilai":{
                    "tugas": 90,
                    "uts": 80,
                    "uas": 70
                }
            },
            {
                "mata_kuliah": "kalkulus 1",
                "hadir": 21,
                "sks": 3,
                "nilai":{
                    "tugas": 70,
                    "uts": 60,
                    "uas": 67,
                }
            },
            {
                "mata_kuliah": "statistika dan probabilitas",
                "hadir": 13,
                "sks": 2,
                "nilai":{
                    "tugas": 90,
                    "uts": 70,
                    "uas": 88
                }
            }
                ]
            },
    {
        "nim": 2046363790,
        "nama": "Sholihin",
        "semester": 8,
        "hasil": [
            {
                "mata_kuliah": "Sistem Penunjang Keputusan",
                "hadir": 19,
                "sks": 3,
                "nilai":{
                    "tugas": 80,
                    "uts": 90,
                    "uas": 65
                }
            },
            {
                "mata_kuliah": "Rekayasa Perangkat Lunak",
                "hadir": 21,
                "sks": 3,
                "nilai":{
                    "tugas": 70,
                    "uts": 80,
                    "uas": 77,
                }
            },
            {
                "mata_kuliah": "Etika Profesi",
                "hadir": 14,
                "sks": 2,
                "nilai":{
                    "tugas": 90,
                    "uts": 80,
                    "uas": 88
                }
            }
                ]
            } 
        ]

# %%
# expected result
results = [
    {
    "nim": "",
    "nama": "",
    "rangkuman_nilai":[
        {
            "mata_kuliah": "",
            "nilai": " : 0 - 100",
            "Grade": ": A | B | C | D | E"
        },	
        {
            "mata_kuliah": "",
            "nilai": " : 0 - 100",
            "Grade": ": A | B | C | D | E"
        }
        ]},
    {
        "nim": "",
        "nama": "",
        "rangkuman_nilai":[
        {
            "mata_kuliah": "",
            "nilai": " : 0 - 100",
            "Grade": ": A | B | C | D | E"
        },
        {
            "mata_kuliah": "",
            "nilai": " : 0 - 100",
            "Grade": ": A | B | C | D | E"
        }
    ]},
]

# %%
# Data Saepulloh

nim = students[1]["nim"]
nama = students[1]["nama"]
print("nim:", nim)
print("nama:", nama)
# statistika dan probabilitas
nama_mk = students[1]["hasil"][2]["mata_kuliah"]
sks = students[1]["hasil"][2]["sks"]
hadir = students[1]["hasil"][2]["hadir"]
print("Mata Kuliah:", nama_mk)
print("Sks:", sks)
print("Kehadiran:", hadir)

tugas = students[1]["hasil"][2]["nilai"]["tugas"]
uts = students[1]["hasil"][2]["nilai"]["uts"]
uas = students[1]["hasil"][2]["nilai"]["uas"]

print("Tugas:", tugas)
print("UTS:", uts)
print("UAS:", uas)
# Out:
# nim: 2046363777
# nama: Saepulloh
# Mata Kuliah: statistika dan probabilitas
# Sks: 2
# Kehadiran: 13
# Tugas: 90
# UTS: 70
# UAS: 88

# %%
for student in students:
    # if student["semester"] <= 5:
    #     continue
    nim = student["nim"]
    nama = student["nama"]
    print("nim:", nim)
    print("nama:", nama)
    for mk in student["hasil"]:
        print("..............................")
        nama_mk = mk["mata_kuliah"]
        sks = mk["sks"]
        hadir = mk["hadir"]
        print("      Mata Kuliah:", nama_mk)
        print("      SKS:", sks)
        print("      Kehadiran:", hadir)
        tugas = mk["nilai"]["tugas"]
        uts = mk["nilai"]["uts"]
        uas = mk["nilai"]["uas"]
        print("      Tugas:", tugas)
        print("      UTS:", uts)
        print("      UAS:", uas)
    print("---------------------------")
# Out:
# nim: 2046363636
# nama: Iwan
# ..............................
#       Mata Kuliah: kecerdasan buatan
#       SKS: 3
#       Kehadiran: 18
#       Tugas: 75
#       UTS: 80
#       UAS: 77
# ..............................
#       Mata Kuliah: basis data 1
#       SKS: 3
#       Kehadiran: 20
#       Tugas: 80
#       UTS: 82
#       UAS: 67
# ..............................
#       Mata Kuliah: digital enterpreneur
#       SKS: 2
#       Kehadiran: 14
#       Tugas: 90
#       UTS: 82
#       UAS: 80
# ---------------------------
# nim: 2046363777
# nama: Saepulloh
# ..............................
#       Mata Kuliah: algoritma & pemrogaman 1
#       SKS: 3
#       Kehadiran: 20
#       Tugas: 90
#       UTS: 80
#       UAS: 70
# ..............................
#       Mata Kuliah: kalkulus 1
#       SKS: 3
#       Kehadiran: 21
#       Tugas: 70
#       UTS: 60
#       UAS: 67
# ..............................
#       Mata Kuliah: statistika dan probabilitas
#       SKS: 2
#       Kehadiran: 13
#       Tugas: 90
#       UTS: 70
#       UAS: 88
# ---------------------------
# nim: 2046363790
# nama: Sholihin
# ..............................
#       Mata Kuliah: Sistem Penunjang Keputusan
#       SKS: 3
#       Kehadiran: 19
#       Tugas: 80
#       UTS: 90
#       UAS: 65
# ..............................
#       Mata Kuliah: Rekayasa Perangkat Lunak
#       SKS: 3
#       Kehadiran: 21
#       Tugas: 70
#       UTS: 80
#       UAS: 77
# ..............................
#       Mata Kuliah: Etika Profesi
#       SKS: 2
#       Kehadiran: 14
#       Tugas: 90
#       UTS: 80
#       UAS: 88
# ---------------------------

# %%
weight = {"hadir": 10, "tugas": 20, "uts":30, "uas":40}

def calculate(sks, hadir, tugas, uts, uas, bobot=weight):
    
    max_hadir = 0
    if sks == 2: 
        max_hadir = 14
    if sks == 3: 
        max_hadir = 21

    if not max_hadir:
        return None, "SKS tidak valid"
    hadir = hadir/max_hadir * bobot["hadir"]
    tugas = tugas/100 * bobot["tugas"]
    uts = uts/100 * bobot["uts"]
    uas = uas/100 * bobot["uas"]
    nilai = hadir + tugas + uts + uas
    return round(nilai,2), None

# %%
tugas = 100
uts = 70
uas =70
hadir = 14
sks = 3

nilai, _err = calculate(sks, hadir,  tugas, uts, uas)
print(nilai, _err)

nilai, _err = calculate(tugas=tugas, hadir=hadir, sks=sks, uas=uas, uts=uts)
print(nilai, _err)
# Out:
# 75.67 None
# 75.67 None
